# %%
from pyanp.priority import *
import numpy as np

# %%
a = np.array([
    [1, 4, 2.],
    [1/4, 1, 1/4],
    [1/2, 4, 1]
])

# %%
pri_eigen(a)
# Out:
# array([ 0.54693056,  0.10852477,  0.34454467])

# %%
pri_llsm(a)
# Out:
# array([ 0.54693056,  0.10852477,  0.34454467])

# %%
pri_expeigen(a)
# Out:
# array([ 0.5736327 ,  0.11561904,  0.31074826])
